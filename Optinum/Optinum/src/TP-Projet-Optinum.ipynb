# %% [markdown]
# <center>
# <h1> TP-Projet d'optimisation numérique </h1>
# <h1> Année 2020-2021 - 2e année département Sciences du Numérique </h1>
# <h1> Noms:  </h1>
# <h1> Prénoms:  </h1>
# </center>

# %% [markdown]
# # Algorithme de Newton
# ## Implémentation
#
# 1. Coder l’algorithme de Newton local tel que décrit dans la section *Algorithme de Newton* (fichier `Algorithme_De_Newton.jl`)
#
# 2. Tester l’algorithme sur les fonctions $f_{1}$ , $f_{2}$ avec les points initiaux $x_{011}$ , $x_{012}$ (pour $f_{1}$ ) et $x_{021}$ , $x_{022}$ , $x_{023}$ (pour $f_{2}$ ) donnés en Annexe A.

# %%
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter

using Calculus
using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
#                                            pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Algorithme_De_Newton.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,sol_exacte,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
	println("  * sol_exacte : ", sol_exacte)
end



# Fonction f0
# -----------
f0(x) =  sin(x)
# la gradient de la fonction f0
grad_f0(x) = cos(x)
# la hessienne de la fonction f0
hess_f0(x) = -sin(x)
sol_exacte = -pi/2
options = []

x0 = sol_exacte
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
x0 = -pi/2+0.5
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
x0 = pi/2
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)

# Fonction f1
# -----------
function f1(x)
    return 2(x[1]+x[2]+x[3]-3)^2+(x[1]-x[2])^2+(x[2]-x[3])^2
end

# la gradient de la fonction f1
function grad_f1(x)
    return Calculus.gradient(y -> f1(y),x)
end

# la hessienne de la fonction f1
function hess_f1(x)
    return hessian(y -> f1(y),x)
end

sol_exacte = [1.0, 1.0, 1.0]
x011 = [1.0, 0.0, 0.0]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f1,grad_f1,hess_f1,x011,options)
my_afficher_resultats("Newton","f1",x011,xmin,f_min,flag,sol_exacte,nb_iters)
x012 = [10.0, 3.0, -2.2]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f1,grad_f1,hess_f1,x012,options)
my_afficher_resultats("Newton","f1",x012,xmin,f_min,flag,sol_exacte,nb_iters)

# Fonction f2
# -----------
# function f2(x)
#     return 100(x[2]-x[1]^2)^2+(1-x[1])^2
# end
# # la gradient de la fonction f2
# function grad_f2(x)
#     return Calculus.gradient(y -> f2(y),x)
# end

# # la hessienne de la fonction f1
# function hess_f2(x)
#     return hessian(y -> f2(y),x)
# end
# Fonction f2
# -----------


f2(x) = 100(x[2]-x[1]^2)^2+(1-x[1])^2

#la gradient de la fonction f1
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]) ; 200*(x[2]-x[1]^2)]

# La hessienne de la fonction f1
hess_f2(x) = [-400*(x[2]-3*x[1]^2)+2  -400*x[1];-400*x[1]  200]

# Les points initiaux 
x021 = [-1.2; 1]
x022 = [10; 0]
x023 = [0; (1/200) + (1/10^(12))]

sol_exacte = [1;1]
options = []

xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x021,options)
my_afficher_resultats("Newton","f2",x021,xmin,f_min,flag,sol_exacte,nb_iters)

xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x022,options)
my_afficher_resultats("Newton","f2",x022,xmin,f_min,flag,sol_exacte,nb_iters)

xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x023,options)
my_afficher_resultats("Newton","f2",x023,xmin,f_min,flag,sol_exacte,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.5707963267948966:
#   * xsol = -1.5707963267948966
#   * f(xsol) = -1.0
#   * nb_iters = 0
#   * flag = 1
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.0707963267948966:
#   * xsol = -1.5707632087735703
#   * f(xsol) = -0.9999999994515983
#   * nb_iters = 2
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial 1.5707963267948966:
#   * xsol = 1.5707963267948966
#   * f(xsol) = 1.0
#   * nb_iters = 0
#   * flag = 1
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f1 au point initial [1.0, 0.0, 0.0]:
#   * xsol = [0.9999868797309541, 1.0000012424732985, 1.0000072981211645]
#   * f(xsol) = 2.8490607729383433e-10
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : [1.0, 1.0, 1.0]
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f1 au point initial [10.0, 3.0, -2.2]:
#   * xsol = [1.0000084056555494, 0.9999939971314258, 0.9999954757866192]
#   * f(xsol) = 2.1879288859052133e-10
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : [1.0, 1.0, 1.0]
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f2 au point initial [-1.2, 1.0]:
#   * xsol = [0.9999956956536585, 0.9999913913256966]
#   * f(xsol) = 1.8527397427294243e-11
#   * nb_iters = 5
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f2 au point initial [10, 0]:
#   * xsol = [1.0000000000000004, 0.9999998672067668]
#   * f(xsol) = 1.763404301624558e-12
#   * nb_iters = 4
#   * flag = 0
#   * sol_exacte : [1, 1]
# SingularException(2)
#
# Stacktrace:
#  [1] checknonsingular at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\LinearAlgebra\src\factorization.jl:19 [inlined]
#  [2] checknonsingular at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\LinearAlgebra\src\factorization.jl:21 [inlined]
#  [3] lu!(::Array{Float64,2}, ::Val{true}; check::Bool) at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\LinearAlgebra\src\lu.jl:85
#  [4] #lu#136 at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\LinearAlgebra\src\lu.jl:273 [inlined]
#  [5] lu at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\LinearAlgebra\src\lu.jl:272 [inlined] (repeats 2 times)
#  [6] \(::Array{Float64,2}, ::Array{Float64,1}) at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\LinearAlgebra\src\generic.jl:1116
#  [7] Algorithme_De_Newton(::typeof(f2), ::typeof(grad_f2), ::typeof(hess_f2), ::Array{Float64,1}, ::Array{Any,1}) at C:\Users\Lotfi\Downloads\Optinum\Optinum\src\Algorithme_De_Newton.jl:62
#  [8] top-level scope at In[4]:108
#  [9] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %% [markdown]
# ## Interprétation
#
# Justifier
#
# 1. les résultats obtenus pour l'exemple $f_0$ ci-dessus;
#
# 2. que l’algorithme implémenté converge en une itération pour $f_{1}$;
#
# 3. que l’algorithme puisse ne pas converger pour $f_{2}$ avec certains points initiaux.

# %% [markdown]
# ## Vos réponses?

# %% [markdown]
# # Régions de confiance avec pas de cauchy
#
# ## Implémentation
#
# 1. Coder l'algorithme du pas de Cauchy d’un sous-problème de
# régions de confiance (fichier `Pas_De_Cauchy.jl`). Tester sur les quadratiques proposées en Annexe B.
#
# 2. Coder l'algorithme de régions de confiance (fichier `Regions_De_Confiance.jl`). Tester sur les problèmes de l’Annexe A.

# %%
# Vos tests
include("Pas_De_Cauchy.jl")
# Quadratique 1 
g1 = [0;0]
H1 = [7 0; 0 2]
delta1 = 1
s1, e1 = Pas_De_Cauchy(g1,H1,delta1)
println(s1,e1)
# Quadratique 2 
g2 = [6;2]
H2 = [7 0; 0 2]
delta1 = 10
s2, e2 = Pas_De_Cauchy(g2,H2,delta1)
println(s2,e2)
# Quadratique 3
g3 = [-2;1]
H3 = [-2 0; 0 10]
delta1 = 10
s3, e3 = Pas_De_Cauchy(g3,H3,delta1)
println(s3,e3)
# Out:
# [0.0, 0.0]0
# [-0.9230769230769234, -0.30769230769230776]1
# [5.000000000000001, -2.5000000000000004]1

# %%
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter

using Calculus
using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
#                                            pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Regions_De_Confiance.jl")
include("Pas_De_Cauchy.jl")
include("Gradient_Conjugue_Tronque.jl")
# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,sol_exacte,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
	println("  * sol_exacte : ", sol_exacte)
end



# Fonction f0
# -----------
f0(x) =  sin(x)
# la gradient de la fonction f0
grad_f0(x) = cos(x)
# la hessienne de la fonction f0
hess_f0(x) = -sin(x)
sol_exacte = -pi/2
options = []

x0 = sol_exacte
algo = "gct"
xmin, fxmin, flag, nb_iters = Regions_De_Confiance(algo,f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("RDC","f0",x0,xmin,fxmin,flag,sol_exacte,nb_iters)
x0 = -pi/2+0.5
xmin, fxmin, flag, nb_iters = Regions_De_Confiance(algo,f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("RDC","f0",x0,xmin,fxmin,flag,sol_exacte,nb_iters)
x0 = pi/2
xmin, fxmin, flag, nb_iters = Regions_De_Confiance(algo,f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("RDC","f0",x0,xmin,fxmin,flag,sol_exacte,nb_iters)

# Fonction f2
# -----------


f2(x) = 100(x[2]-x[1]^2)^2+(1-x[1])^2

#la gradient de la fonction f1
grad_f2(x) = [-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]) ; 200*(x[2]-x[1]^2)]

# La hessienne de la fonction f1
hess_f2(x) = [-400*(x[2]-3*x[1]^2)+2  -400*x[1];-400*x[1]  200]

# Les points initiaux 
x021 = [-1.2; 1]
x022 = [10; 0]
x023 = [0; (1/200) + (1/10^(12))]

sol_exacte = [1;1]
options = []

xmin, fxmin, flag, nb_iters = Regions_De_Confiance(algo,f2,grad_f2,hess_f2,x021,options)
my_afficher_resultats("RDC","f2",x021,xmin,fxmin,flag,sol_exacte,nb_iters)
xmin, fxmin, flag, nb_iters = Regions_De_Confiance(algo,f2,grad_f2,hess_f2,x022,options)
my_afficher_resultats("RDC","f2",x022,xmin,fxmin,flag,sol_exacte,nb_iters)

xmin, fxmin, flag, nb_iters = Regions_De_Confiance(algo,f2,grad_f2,hess_f2,x023,options)
my_afficher_resultats("RDC","f2",x023,xmin,fxmin,flag,sol_exacte,nb_iters)

# Fonction f1
# -----------
function f1(x)
    return 2(x[1]+x[2]+x[3]-3)^2+(x[1]-x[2])^2+(x[2]-x[3])^2
end

# la gradient de la fonction f1
function grad_f1(x)
    return Calculus.gradient(y -> f1(y),x)
end

# la hessienne de la fonction f1
function hess_f1(x)
    return hessian(y -> f1(y),x)
end

sol_exacte = [1.0, 1.0, 1.0]
x011 = [1.0, 0.0, 0.0]
xmin, fxmin, flag, nb_iters = Regions_De_Confiance(algo,f1,grad_f1,hess_f1,x011,options)
my_afficher_resultats("RDC","f1",x011,xmin,fxmin,flag,sol_exacte,nb_iters)

x012 = [10.0, 3.0, -2.2]
xmin,f_min,flag,nb_iters = Regions_De_Confiance(algo,f1,grad_f1,hess_f1,x012,options)
my_afficher_resultats("RDC","f1",x012,xmin,f_min,flag,sol_exacte,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : RDC appliqué à f0 au point initial -1.5707963267948966:
#   * xsol = -1.5707963267948966
#   * f(xsol) = -1.0
#   * nb_iters = 0
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : RDC appliqué à f0 au point initial -1.0707963267948966:
#   * xsol = -1.5707632087735703
#   * f(xsol) = -0.9999999994515983
#   * nb_iters = 2
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : RDC appliqué à f0 au point initial 1.5707963267948966:
#   * xsol = -1.5717502162793813
#   * f(xsol) = -0.9999995450474601
#   * nb_iters = 4
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : RDC appliqué à f2 au point initial [-1.2, 1.0]:
#   * xsol = [0.999999674378009, 0.9999993478371609]
#   * f(xsol) = 1.0611413034983129e-13
#   * nb_iters = 31
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : RDC appliqué à f2 au point initial [10, 0]:
#   * xsol = [1.0000035183009863, 1.0000066949336202]
#   * f(xsol) = 2.4053014026923312e-11
#   * nb_iters = 44
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : RDC appliqué à f2 au point initial [0.0, 0.0050000000010000005]:
#   * xsol = [0.9999995779640825, 0.9999991547367848]
#   * f(xsol) = 1.78256296790364e-13
#   * nb_iters = 18
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : RDC appliqué à f1 au point initial [1.0, 0.0, 0.0]:
#   * xsol = [0.9999868797262634, 1.0000012424677804, 1.0000072981164176]
#   * f(xsol) = 2.8490633684346925e-10
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : [1.0, 1.0, 1.0]
# -------------------------------------------------------------------------
# Résultats de : RDC appliqué à f1 au point initial [10.0, 3.0, -2.2]:
#   * xsol = [1.0000045330449234, 1.0000000506674378, 0.9999959793054964]
#   * f(xsol) = 3.7301674197312316e-11
#   * nb_iters = 3
#   * flag = 0
#   * sol_exacte : [1.0, 1.0, 1.0]

# %% [markdown]
# ## Interprétation
#
# 1. Quelle relation lie la fonction test $f_1$ et son modèle de Taylor à l’ordre 2 ? Comparer alors les performances de Newton et RC-Pas de Cauchy sur cette fonction.
#
# 2. Le rayon initial de la région de confiance est un paramètre important dans l’analyse
# de la performance de l’algorithme. Sur quel(s) autre(s) paramètre(s) peut-on jouer
# pour essayer d’améliorer cette performance ? Étudier l’influence d’au moins deux de
# ces paramètres.

# %% [markdown]
# ## Vos réponses?

# %% [markdown]
# # Régions de confiance avec gradient conjugué tronqué
#
# ## Implémentation
#
# 1. Implémenter l’algorithme du Gradient Conjugué Tronqué, en se basant sur le cours (fichier `Gradient_Conjugue_Tronque.jl`).
# On validera les résultats sur les fonctions de l’Annexe C.
#
# 2. Intégrer finalement l’algorithme du Gradient Conjugué Tronqué dans le code de
# régions de confiance, et appliquer ce code pour résoudre les exemples proposés en
# Annexe A.

# %%
# Vos tests

# %% [markdown]
# ## Interprétation
#
# 1. Comparer la décroissance obtenue avec celle du pas de Cauchy, en retournant, dans
# un premier temps le dernier itéré admissible à courbure positive (c’est à dire, que si
# l’une ou l’autre des deux conditions (b) ou (d) sont rencontrées dans l’algorithme 3,
# alors on ne calcule pas ``σ_{j}`` et on retourne le dernier itéré ``s_{j}`` directement).
#
# 2. Comparer la décroissance obtenue avec celle du pas de Cauchy, en imposant la sortie
# dans l’algorithme 3 au bout d’une itération seulement. Que remarquez vous ?
#
# 3. Comparer la décroissance obtenue avec celle du pas de Cauchy dans le cas général.
#
# 4. Quels sont les avantages et inconvénients des deux approches ?

# %% [markdown]
# ## Vos réponses?

# %% [markdown]
# # Lagrangien augmenté
#
# ## Implémentation
# 1.Choisir des critères d’arrêt pour la convergence de l'algorithme.
#
# 2.Implémenter l'algorithme du lagrangien augmenté, en utilisant les différentes méthodes
# qui ont été vues en première partie pour la résolution de la suite de problémes sans
# contraintes (fichier `Lagrangien_Augmente.jl`)
#
# 3.Tester les différentes variantes sur les problèmes en Annexe D.

# %%
# Vos tests
 #using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
                                           # pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Regions_De_Confiance.jl")
include("Pas_De_Cauchy.jl")
include("Gradient_Conjugue_Tronque.jl")
include("Algorithme_De_Newton.jl")
include("Lagrangien_Augmente.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats_2(algo,nom_fct,point_init,xmin,fxmin,flag,nbiters)
    println("-------------------------------------------------------------------------")
    printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
    println("  * xsol = ",xmin)
    println("  * f(xsol) = ",fxmin)
    println("  * nb_iters = ",nbiters)
    println("  * flag = ",flag)
end

f(x)=100*(x[2]-x[1]^2)^2+(1-x[1])^2
gradf(x)=[-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]) ; 200*(x[2]-x[1]^2)]
hessf(x)=[-400*(x[2]-3*x[1]^2)+2  -400*x[1];-400*x[1]  200]
algo = "cauchy" # ou newton|gct
x0 = [sqrt(3)/2; sqrt(3)/2]
options = []
contrainte(x) =  (x[1]^2) + (x[2]^2) -1.5
grad_contrainte(x) = [2*x[1] ;2*x[2]]
hess_contrainte(x) = [2 0;0 2]
xmin,f_min,flag,nb_iters = Lagrangien_Augmente(algo,f,contrainte,gradf,hessf,grad_contrainte,hess_contrainte,x0,options)

my_afficher_resultats_2(algo,f,x0,xmin,f_min,flag,nb_iters)
# Out:
# UndefVarError: xk1 not defined
#
# Stacktrace:
#  [1] Lagrangien_Augmente(::String, ::typeof(f), ::typeof(contrainte), ::typeof(gradf), ::typeof(hessf), ::typeof(grad_contrainte), ::typeof(hess_contrainte), ::Array{Float64,1}, ::Array{Any,1}) at C:\Users\Lotfi\Downloads\Optinum\Optinum\src\Lagrangien_Augmente.jl:118
#  [2] top-level scope at In[9]:33
#  [3] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %% [markdown]
# ## Interprétation
#  1.Commenter les résultats obtenus, en étudiant notamment les valeurs de $\lambda_k$ et $\mu_k$.
#
#  2.Étudier l'influence du paramètre $\tau$ dans la performance de l'algorithme.
#
#  3.**Supplémentaire** :
#       Que proposez-vous comme méthode pour la résolution des problèmes avec
#       des contraintes à la fois d'égalité et d'inégalité ? Implémenter (si le temps le permet)
#       ce nouvel algorithme

# %% [markdown]
# ## Vos réponses?
